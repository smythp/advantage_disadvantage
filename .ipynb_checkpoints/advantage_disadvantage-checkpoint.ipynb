# %%
from puzzle import df
# Out:
# Regular die
#
# count    1000000.000000
# mean          10.505368
# std            5.763381
# min            1.000000
# 25%            6.000000
# 50%           11.000000
# 75%           16.000000
# max           20.000000
# dtype: float64
# Analysis complete in 2.653719186782837 seconds
#
#
# advantage
#
# count    1000000.000000
# mean          13.828089
# std            4.710086
# min            1.000000
# 25%           10.000000
# 50%           15.000000
# 75%           18.000000
# max           20.000000
# dtype: float64
# Analysis complete in 5.261429071426392 seconds
#
#
# disadvantage
#
# count    1000000.000000
# mean           7.175315
# std            4.711611
# min            1.000000
# 25%            3.000000
# 50%            6.000000
# 75%           10.000000
# max           20.000000
# dtype: float64
# Analysis complete in 5.299631357192993 seconds
#
#
# Advantage of disadvantage
#
# count    1000000.000000
# mean           9.832749
# std            4.433409
# min            1.000000
# 25%            6.000000
# 50%           10.000000
# 75%           13.000000
# max           20.000000
# dtype: float64
# Analysis complete in 10.887674570083618 seconds
#
#
# Disadvantage of advantage
#
# count    1000000.000000
# mean          11.160634
# std            4.427099
# min            1.000000
# 25%            8.000000
# 50%           11.000000
# 75%           15.000000
# max           20.000000
# dtype: float64
# Analysis complete in 10.592431783676147 seconds

# %%
dice_plot = df.plot(title='')

dice_plot.set_xlabel("Percentage Chance of Rolling Over")
dice_plot.set_ylabel("Dice Roll")
# Out:
# Text(0, 0.5, 'Dice Roll')

# %%
drop_columns_df = df[['Regular die', 'Advantage of disadvantage',
             'Disadvantage of advantage']]

drop_columns_df
# Out:
#     Regular die  Advantage of disadvantage  Disadvantage of advantage
# 1        0.9502                     0.9905                     0.9951
# 2        0.9000                     0.9638                     0.9801
# 3        0.8501                     0.9226                     0.9555
# 4        0.8001                     0.8697                     0.9215
# 5        0.7502                     0.8078                     0.8787
# 6        0.7004                     0.7389                     0.8281
# 7        0.6503                     0.6655                     0.7698
# 8        0.6001                     0.5900                     0.7051
# 9        0.5500                     0.5129                     0.6356
# 10       0.5001                     0.4369                     0.5622
# 11       0.4498                     0.3637                     0.4862
# 12       0.3996                     0.2943                     0.4091
# 13       0.3498                     0.2297                     0.3329
# 14       0.3001                     0.1710                     0.2600
# 15       0.2499                     0.1202                     0.1911
# 16       0.2002                     0.0777                     0.1292
# 17       0.1504                     0.0443                     0.0770
# 18       0.1003                     0.0199                     0.0361
# 19       0.0504                     0.0050                     0.0094
# 20      -0.0000                     0.0000                     0.0000

# %%
drop_columns_df.idxmax(axis=1)
# Out:
# 1     Disadvantage of advantage
# 2     Disadvantage of advantage
# 3     Disadvantage of advantage
# 4     Disadvantage of advantage
# 5     Disadvantage of advantage
# 6     Disadvantage of advantage
# 7     Disadvantage of advantage
# 8     Disadvantage of advantage
# 9     Disadvantage of advantage
# 10    Disadvantage of advantage
# 11    Disadvantage of advantage
# 12    Disadvantage of advantage
# 13                  Regular die
# 14                  Regular die
# 15                  Regular die
# 16                  Regular die
# 17                  Regular die
# 18                  Regular die
# 19                  Regular die
# 20                  Regular die
# dtype: object
