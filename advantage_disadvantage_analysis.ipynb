# %%
from puzzle import df
from matplotlib. import savefig
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-10-b297cdd953ad> in <module>
#       1 from puzzle import df
# ----> 2 from matplotlib.plotly import savefig
#
# ModuleNotFoundError: No module named 'matplotlib.plotly'

# %%
dice_plot = df.plot(title='')

dice_plot.set_xlabel("Dice Roll")
dice_plot.set_ylabel("Percentage Chance of Rolling Over")


savefig('dice_plot.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-8f90f71e2ba9> in <module>
#       5
#       6
# ----> 7 savefig('dice_plot.png')
#
# NameError: name 'savefig' is not defined

# %%
drop_columns_df = df[['Regular die', 'Advantage of disadvantage',
             'Disadvantage of advantage']]

drop_columns_df
# Out:
#     Regular die  Advantage of disadvantage  Disadvantage of advantage
# 1        0.9498                     0.9905                     0.9951
# 2        0.8997                     0.9639                     0.9800
# 3        0.8497                     0.9233                     0.9555
# 4        0.8000                     0.8708                     0.9214
# 5        0.7496                     0.8090                     0.8787
# 6        0.6998                     0.7403                     0.8280
# 7        0.6497                     0.6669                     0.7700
# 8        0.5997                     0.5901                     0.7058
# 9        0.5496                     0.5133                     0.6359
# 10       0.4999                     0.4370                     0.5626
# 11       0.4494                     0.3640                     0.4868
# 12       0.3998                     0.2945                     0.4095
# 13       0.3501                     0.2297                     0.3329
# 14       0.2999                     0.1717                     0.2593
# 15       0.2503                     0.1213                     0.1911
# 16       0.2001                     0.0786                     0.1293
# 17       0.1501                     0.0447                     0.0767
# 18       0.1004                     0.0201                     0.0359
# 19       0.0504                     0.0050                     0.0094
# 20       0.0000                    -0.0000                     0.0000

# %%
drop_columns_df.idxmax(axis=1)
# Out:
# 1     Disadvantage of advantage
# 2     Disadvantage of advantage
# 3     Disadvantage of advantage
# 4     Disadvantage of advantage
# 5     Disadvantage of advantage
# 6     Disadvantage of advantage
# 7     Disadvantage of advantage
# 8     Disadvantage of advantage
# 9     Disadvantage of advantage
# 10    Disadvantage of advantage
# 11    Disadvantage of advantage
# 12    Disadvantage of advantage
# 13                  Regular die
# 14                  Regular die
# 15                  Regular die
# 16                  Regular die
# 17                  Regular die
# 18                  Regular die
# 19                  Regular die
# 20                  Regular die
# dtype: object
