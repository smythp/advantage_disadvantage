# %%
from matplotlib.pyplot import savefig
from puzzle import df
# Out:
# Regular die
#
# count    1000000.000000
# mean          10.496887
# std            5.764939
# min            1.000000
# 25%            5.000000
# 50%           11.000000
# 75%           15.000000
# max           20.000000
# dtype: float64
# Analysis complete in 3.090970516204834 seconds
#
#
# Advantage
#
# count    1000000.000000
# mean          13.832228
# std            4.708544
# min            1.000000
# 25%           11.000000
# 50%           15.000000
# 75%           18.000000
# max           20.000000
# dtype: float64
# Analysis complete in 9.175001621246338 seconds
#
#
# Disadvantage
#
# count    1000000.000000
# mean           7.164438
# std            4.709445
# min            1.000000
# 25%            3.000000
# 50%            6.000000
# 75%           10.000000
# max           20.000000
# dtype: float64
# Analysis complete in 9.163456439971924 seconds
#
#
# Advantage of disadvantage
#
# count    1000000.000000
# mean           9.828600
# std            4.426033
# ...

# %%
dice_plot = df.plot(title='')

dice_plot.set_xlabel("Dice Roll")
dice_plot.set_ylabel("Percentage Chance of Rolling Over")


savefig('dice_plot.png')

# %%
drop_columns_df = df[['Regular die', 'Advantage of disadvantage',
             'Disadvantage of advantage']]

drop_columns_df
# Out:
#     Regular die  Advantage of disadvantage  Disadvantage of advantage
# 1        0.9499                     0.9905                     0.9949
# 2        0.8999                     0.9638                     0.9799
# 3        0.8500                     0.9230                     0.9553
# 4        0.7998                     0.8704                     0.9213
# 5        0.7499                     0.8083                     0.8785
# 6        0.6999                     0.7400                     0.8274
# 7        0.6495                     0.6668                     0.7695
# 8        0.5998                     0.5907                     0.7050
# 9        0.5500                     0.5140                     0.6353
# 10       0.4998                     0.4377                     0.5622
# 11       0.4500                     0.3644                     0.4863
# 12       0.3998                     0.2946                     0.4099
# ...

# %%
drop_columns_df.idxmax(axis=1)
# Out:
# 1     Disadvantage of advantage
# 2     Disadvantage of advantage
# 3     Disadvantage of advantage
# 4     Disadvantage of advantage
# 5     Disadvantage of advantage
# 6     Disadvantage of advantage
# 7     Disadvantage of advantage
# 8     Disadvantage of advantage
# 9     Disadvantage of advantage
# 10    Disadvantage of advantage
# 11    Disadvantage of advantage
# 12    Disadvantage of advantage
# 13                  Regular die
# 14                  Regular die
# 15                  Regular die
# 16                  Regular die
# 17                  Regular die
# 18                  Regular die
# 19                  Regular die
# 20                  Regular die
# dtype: object
